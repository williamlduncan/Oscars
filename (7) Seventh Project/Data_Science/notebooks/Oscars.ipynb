# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#I decided to try some visualizations for the NFL dataset that we had available for the third project in this course. 
#Load in the data

# %%
df = pd.read_csv('../data/nfl_games.csv')

# %%
df.head(5)
# Out:
#          date  season  neutral  playoff team1 team2      elo1      elo2  \
# 0  1920-09-26    1920        0        0   RII   STP  1503.947  1300.000
# 1  1920-10-03    1920        0        0   AKR   WHE  1503.420  1300.000
# 2  1920-10-03    1920        0        0   RCH   ABU  1503.420  1300.000
# 3  1920-10-03    1920        0        0   DAY   COL  1493.002  1504.908
# 4  1920-10-03    1920        0        0   RII   MUN  1516.108  1478.004
#
#    elo_prob1  score1  score2  result1
# 0   0.824651      48       0      1.0
# 1   0.824212      43       0      1.0
# 2   0.824212      10       0      1.0
# 3   0.575819      14       0      1.0
# 4   0.644171      45       0      1.0

# %% [raw]
# #Based on the data features here, some ideas might be a violin plot of the result1 variable and some scatterplots looking at
# #score1 and score2 as well as splitting by whether the game was in a playoff or not and looking at elo_prob1's distibution.

# %%
#Below is the violin plot for result1 where 0 is a loss, 1 is a win, and 0.5 is a draw

# %%
sns.violinplot(x = "result1", data=df)

# %%
#I wanted to try a swarm plot for result1 and score1, but couldn't quite get it to work in Python.

# %%
sns.swarmplot(x="result1", y="score1", data=df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-80bb52139011> in <module>()
# ----> 1 sns.swarmplot(x="result1", y="score1", data=df)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2798                        linewidth=linewidth))
#    2799
# -> 2800     plotter.plot(ax, kwargs)
#    2801     return ax
#    2802
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1433     def plot(self, ax, kws):
#    1434         """Make the full plot."""
# -> 1435         self.draw_swarmplot(ax, kws)
#    1436         self.add_legend_data(ax)
#    1437         self.annotate_axes(ax)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_swarmplot(self, ax, kws)
# ...

# %%
#Below is a factor plot with result1 on the x-axis and score1 on the y-axis. The data is split by regular season and playoff
#games and this was a nice graph to show that the scores were higher in the playoffs regardless if the teams won or lost. 
#Note: There are of course no ties in playoffs so no green bar for the 0.5.

# %%
g = sns.factorplot("result1", "score1", "playoff", data=df, kind="bar", palette="muted", legend=False)

# %%
#Below, I was trying to get some of the data points to cluster but obviously to no avail. There might be a nice way to 
#cluster this dataset, but I wasn't quite able to find the right thing. What is below is just one example of a variety of 
#ideas.

# %%
from matplotlib.colors import ListedColormap
current_palette = sns.color_palette("muted", n_colors=5)
cmap = ListedColormap(sns.color_palette(current_palette).as_hex())
N = 16007

# Data
data1=df.score1
data2=df.score2

# Assume that there are 5 possible labels
colors = np.random.randint(0,5,N)

# %%
# Create a scatter plot
plt.scatter(data1, data2, 
c=colors, cmap=cmap)

# %%
#The plots below were a fun idea to try to see whether different teams were scoring higher or lower than other teams over
#time. Here you can see that there are definitely teams that perform consistently better or worse than others, but I can't 
#quite figure out how to get the y-axis to be more readable. I looked on Google for a bit but didn't see a fix specifically for 
#this case.

# %%
ax = sns.swarmplot(x="team1", y="score1", data=df)

# %%
ax.set(xlim=(0,100))
# Out:
# [(0, 100)]

# %%
sns.swarmplot(x="team1", y="score2", data=df)

# %%
sns.swarmplot(x="team2", y="score1", data=df)

# %%
sns.swarmplot(x="team2", y="score2", data=df)

# %%
#The plots below were an idea that there might be a point at which all teams won and all teams generally lost if they scored
#a certain number of points. It seems like the plots below indicate that is generally not true, though 40 might be a good
#cut-off where almost every team wins with more than 40 points.

# %%
x=df.score1
y=df.result1
plt.plot(x, y)

# %%
x1=df.score2
y1=df.result1
plt.plot(x,y)

# %%
x2=df.result1
y2=df.elo_prob1
plt.plot(x2,y2)
